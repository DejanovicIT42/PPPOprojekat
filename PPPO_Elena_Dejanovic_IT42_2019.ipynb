# %% [markdown]
# <a href="https://colab.research.google.com/github/DejanovicIT42/PPPOprojekat/blob/main/PPPO_Elena_Dejanovic_IT42_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="right">
#
# *Univerzitet u Novom Sadu*
#
# *Fakultet Tehničkih Nauka*
#
# *Departmen za industrijsko inženjerstvo i menadžment*
# <div>

# %% [markdown]
# <div align="center">
#
# # Projektni zadatak iz predmeta "Principi prezentacije i prepoznavanja oblika"
#
# ---
# <div>
#
#
#
# <div align="left">
#
# **Student:** Elena Dejanović IT42/2019
#
# **Tema:** Segmentacija ultrazvuka
# <div>
#
# <div align="center">
#
# Novi Sad, 2023.
# <div>

# %% [markdown]
# ---
#
# # **Sadržaj**
#
# 1.   Uvod
# 2.   Segmentacija
#   1.   Tehnike segmentacije
# 3.   Projektni zadatak
#   1.   Set podataka
#   2.   Model
#   2.   Treniranje modela
#   2.   Evaluacija
#   2.   Testiranje
#
# 4.   Zaključak
# 5.   Reference
#
# ---
#
# # **1. Uvod**
# U projektu iz predmeta Principi prezentacije i prepoznavanja oblika će u narednim poglavljima biti obrađena tema primene segmentacije u sferi medicine.Segmentacija ultrazvučnih slika ima za cilj da što bolje prikaže određeno područje ljudskog tela kako bi olakšalo lekarima u otkrivanju anomalija na obrađenim snimcima.
#
# Cilj segmentacije ultrazvučnih slika u ovom projektu je da se otkloni količina buke nastale na snimcima tokom procesa izrade ultrazvuka [3]. Na ovaj način se poboljšava šansa da lekarsko osoblje dobije što jasniji prikaz stanja pacijenta.
#
# U narednom delu projekta biće kratko rečeno o samom procesu segmentacije, šta predstavlja, kako funkcioniše i koji algoritmi i tehnike segmentacije mogu da se primene na ovaj zadatak. Zatim, u praktičnom delu će se kroz korake prikazati sam princip rada.
#
#
# # **2. Segmentacija**
#
# Segmentacija je proces podele jedne slike na više segmenata (podgrupa) slike. Segment u tom slučaju predstavlja skup piksela na koje se deli slika, gde svaka regija sadrži piksele sa sličnim atributima. Dakle, segmentacija predstavlja postupak dodeljivanja oznaka pikselima, tako da svi elementi slike odnosno svi pikseli koji pripadaju istom segmentu imaju zajedničku oznako koja im je dodeljena jer dele određene osobine [1].
#
#
# **2.1 Tehnike segmentacije**
#
# Postoji nekoliko jedinstvenih prilaza segmentiranju slika.
# Metode segmentacije slike traže objekte koji imaju neku meru homogenosti u sebi, ili imaju neku meru kontrasta na svojim granicama u odnosu na druge objekte. Većina algoritama za segmentaciju slike su modifikacije, proširenja ili kombinacije ova dva osnovna koncepta. Mere homogenosti i kontrasta mogu uključivati karakteristike kao što su nivo sive boje, ostalih boja i tekstura [1].
# Najpopularinja podela na algoritme tehnika segmentacije:
#
# 1.   Segmentacija zasnovana na pragu (**Tresholding**)
#
#   **Segmentacija pragom** predstavlja grupu metoda zasnovanih na poređenju osvetljenosti piksela sa jednim ili više pragova, pa tako postoji segmentacija sa jednim ili segmentacija sa više pragova. Ukoliko su u pitanju slike u boji tada se vrši poređenje boje između piksela. Segmentacija sa jednim pragom je najjednostavniji vid segmentacije i njegova osnovna primena je za odvajanje objekta od pozadine, ukoliko pozadina ima uniformnu osvetljenost (boju) koja se razlikuje od objekta. Ovakav način segmentacije se može primeniti, između ostalog, i kod izdvajanja nekog teksta, analize nekih medicinskih slika, prepoznavanja tipa aviona koji leti, itd. Segmentacija sa više pragova je metoda koju je pogodno koristiti u slučaju kada su u pitanju scene sa više različitih objekata [2].
#
#
# 2.   Segmentacija klasterizacijom (**Clustering**)
#
#   **Klasterizacija (grupisanje)** je vrsta algoritma za mašinsko učenje bez nadzora i često se koristi za segmentaciju fotografija. Jedan od najdominantnijih algoritama zasnovanih na grupisanju koji se koristi za segmentaciju je *KMeans Clustering*. Ova vrsta grupisanja uglavnom koristi za pravljenje segmenata fotografija u boji, ali i sivih fotografija. Postupak segmentacije se u tom slučaju sastoji od podele N–dimenzionalnog prostora u uzajamno isključive oblasti, pri čemu svaka ta oblast obuhvata grupu podataka koja se odnosi na jedan region slike. Takav proces podele prema sličnosti vektora podataka se naziva klasterizacija. U prvoj fazi segmentacije se izračuna i izdvaja na obeležja. Zatim se određuje optimalan broj klastera, kao i skupa vektora koji predstavljaju centre svakog klastera. Nakon toga svaki piksel se pridružuje jednom od klastera. Pridruživanje se vrši na osnovu sličnosti vektora koji opisuje piksel i vektora koji opisuje centar klastera [2].
#
#   Ova metoda je sa dosta uspeha primenjivana u segmentaciji multispektralnih satelitskih ili avionskih snimaka. Nedostatak ove metode je što ima veliku računsku složenost.
#
# 3.   Segmentacija regiona (**Region-based**)
#
#   **Segmentacija regiona** predstavlja skup metoda koje pokušavaju da izdvoje područja slike koja su homogena sa gledišta određenih karakteristika [2]. U ovu grupu spadaju:
#
#   1.   Segmentacija pomoću rasta regiona
#
#       Osnovna ideja **segmentacije pomoću rasta regiona** je da se izvrši grupisanje susednih piksela sličnih osvetljenosti (boja), na osnovu čega se formiraju regioni. Metoda rasta regiona je naročito pogodna kod segmentacije prostih scena sa malim brojem objekata i slabom teksturom [2].
#
#   2.   Segmentacija pomoću razdvajanja i spajanja regiona
#
#       Kod **segmentacije pomoću razdvajanja i spajanja regiona**, slika se deli na četiri kvadranta, nakon čega se ispituje da li su dobijeni podsegmenti uniformni po obeležju na osnovu kojeg se vrši segmentacija [2].
#
#   **Region** je grupa povezanih piksela koji pokazuju slična svojstva. Oni se mogu postaviti na primer, na osnovu intenziteta, boje i sl. U ovoj vrsti segmentacije prisutna su unapred definisana pravila koja piksel mora da ispuni kako bi bio klasifikovan u određeni region.
#
#   Metode zasnovane na regionima su poželjnije od ostalih u slučaju kada se radi segmentacija slika sa smetnjama (kao što je to slučaj pri ultrazvuku) [3].
#
# 4.   Segmentacija granica (**Edge detection**)
#
#   U procesu **segmentacije koji koristi ivice (granice regiona)** mora se primeniti i postupak za spajanje ivica, kako bi se formirale neprekidne granice regiona. Razlog za to je što metode koje vrše izdvajanje ivica generišu isprekidane granice objekata, a ne zatvorene krive. U tu svrhu se mogu koristiti: metoda spajanja ivica fitovanjem krive, spajanje ivica heurističkim metodama i spajanje ivica Hafovom transformacijom. Metodom fitovanja krivih se mogu rekonstruisati nedostajući segmenti ukoliko mapa ivica sadrži prekinute ivice. Fitovanje krivih je najjednostavnije kada nam je poznat oblik krive, pa se nedostajući segment dobija fitovanjem npr. pravih ili kružnih oblika. Kada su granice regiona složenije, vrši se razlaganje granice na jednostavnije delove. Glavna prednost ove metode je njena izuzetna jednostavnost i to da daje dobre rezultate prilikom segmentacije jednostavnih scena [2].
#
#   Međutim, kod slika na kojima postoji veći broj objekata koji se preklapaju, mapa ivica sadrži tačke grananja, pa u tom slučaju ova metoda ne daje dobre rezultate. Kod heurističkih metoda za spajanje ivica se prvo formira gradijentna slika primenom odgovarajućih maski. Cilj segmentacije ivica je da dobijemo srednji rezultat segmentacije na koji možemo primeniti segmentaciju zasnovanu na regionu ili bilo koju drugu vrstu segmentacije da bismo dobili konačnu segmentiranu sliku [2].
#
#   **2.2. Intersection over Union (IoU)**
#
#   Razlika između preseka i unije.
#   IoU se obično koristi kao metrika evaluacije tokom obuke modela za procenu performansi modela segmentacije. Pruža kvantitativnu meru koliko dobro model može precizno segmentirati objekte ili regione od interesa na slici.
#
# ![joooo.png](data:image/png;base64,...)
#
# # **3. Projektni zadatak**
#
# **3.1. Set podataka**
#
#   Dobijeni dataset se sastoji iz ultrazvučnih snimaka i maski za svaki snimak (fotografiju). Set podataka koji je obrađivan u ovom projektu se sastoji od:
#
# 1.	**train foldera** - sadrži slike koje se koriste za treniranje modela. Postoje dve vrste slika u ovom folderu, slike ultrazvuka nerava i slike maski tih slika. Za svaku osobu postoji veći broj snimaka. Svaki snimak sa istim početnim brojem pripada istom pacijentu. Uz pomoć druge slike (maske) se zna da li i gde je identifikovan nerv na prvoj slici.
#
# 2.	**test foldera** - sadrži slike za testiranje modela. Cilj je predvideti segmentaciju za ove slike i na njima nije dat broj osobe na koju se odnose, jer je predviđeno da model sam vrši procenu. Nema preklapanja između slika koje se nalaze u trening i test setovima podataka.
#
# 3.	**train_masks.csv** - daje maske slika treninga u kodiranom formatu. Naznačeno je koji pikseli slike obuhvataju nerv na konkretnoj slici.
#
# 4.	**sample_submission.csv** fajla - služi kao primer konačnih rezultata

# %% [markdown]
# Jedan od načina da se učita ovaj set podataka jeste:
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# ```

# %% [markdown]
# Međutim, postoji i drugi način da se preuzme set podataka koji ćemo koristiti za izradu ovog projekta:

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1W66UP2jO5TkIrOrr7xmqvT9mvMsiYwv9' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1W66UP2jO5TkIrOrr7xmqvT9mvMsiYwv9" -O images.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-07-10 21:43:05--  https://docs.google.com/uc?export=download&confirm=t&id=1W66UP2jO5TkIrOrr7xmqvT9mvMsiYwv9
# Resolving docs.google.com (docs.google.com)... 172.217.194.113, 172.217.194.101, 172.217.194.139, ...
# Connecting to docs.google.com (docs.google.com)|172.217.194.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-14-3s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5p8jvm2ji1tmah63uogl1g4g3do4ddql/1689025350000/18096677952522330876/*/1W66UP2jO5TkIrOrr7xmqvT9mvMsiYwv9?e=download&uuid=c120f3ac-4b06-4ed5-aaa4-6171f9bccd8e [following]
# ...
# --2023-07-10 21:43:06--  https://doc-14-3s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5p8jvm2ji1tmah63uogl1g4g3do4ddql/1689025350000/18096677952522330876/*/1W66UP2jO5TkIrOrr7xmqvT9mvMsiYwv9?e=download&uuid=c120f3ac-4b06-4ed5-aaa4-6171f9bccd8e
# ...

# %% [markdown]
# Raspakujemo podatke za treniranje

# %%
# !unzip images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/34_114_mask.tif
#   inflating: train/34_115.tif
#   inflating: train/34_115_mask.tif
#   inflating: train/34_116.tif
#   inflating: train/34_116_mask.tif
#   inflating: train/34_117.tif
#   inflating: train/34_117_mask.tif
#   inflating: train/34_118.tif
#   inflating: train/34_118_mask.tif
#   inflating: train/34_119.tif
#   inflating: train/34_119_mask.tif
#   inflating: train/34_11_mask.tif
#   inflating: train/34_12.tif
#   inflating: train/34_12_mask.tif
#   inflating: train/34_13.tif
#   inflating: train/34_13_mask.tif
#   inflating: train/34_14.tif
#   inflating: train/34_14_mask.tif
#   inflating: train/34_15.tif
#   inflating: train/34_15_mask.tif
#   inflating: train/34_16.tif
#   inflating: train/34_16_mask.tif
#   inflating: train/34_17.tif
#   inflating: train/34_17_mask.tif
#   inflating: train/34_18.tif
#   inflating: train/34_18_mask.tif
#   inflating: train/34_19.tif
# ...

# %% [markdown]
# Dodavanje bibliteka koje su nam neophodne za rad
#
# > PyTorch je framework otvorenog koda koji sadrži neuronske mreže za segmentaciju slika. Zasnovan je na Python i Torch bibliotekama
#
#
# *   Instalacija **segmentation_models_pytorch**

# %%
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch
# Out:
# ...
#   Cloning https://github.com/qubvel/segmentation_models.pytorch to /tmp/pip-req-build-dq03dgas
#   Running command git clone --filter=blob:none --quiet https://github.com/qubvel/segmentation_models.pytorch /tmp/pip-req-build-dq03dgas
#   Resolved https://github.com/qubvel/segmentation_models.pytorch to commit e5d3db20e9c2ddb76f88642409e527239943c983
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 85.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 34.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 72.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# > Early stopping je tehnika u PyTorch-u koja će prekinuti *overfitting* proces onda kada se rezultati ne budu znatno poboljšavali tokom treniranja modela.
#
# *   Kloniranje **early-stopping-pytorch**

# %%
# !git clone https://github.com/Bjarten/early-stopping-pytorch.git esp
# Out:
# Cloning into 'esp'...
# remote: Enumerating objects: 92, done.
# remote: Total 92 (delta 0), reused 0 (delta 0), pack-reused 92
# Unpacking objects: 100% (92/92), 533.87 KiB | 9.05 MiB/s, done.

# %% [markdown]
# Dodavanje potrebnih modula i biblioteka.
# Za ovaj projekat koristi se *PyTorch*, odnosno torchvision paket koji sadrži popularne setova podataka, arhitekture modela i tipičnih transformacija slike za kompijutersku viziju [4].
#
# Pored toga biće importovane potrebne biblioteke za rad sa slikama, listama i grafičkim prikazima.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from esp.pytorchtools import EarlyStopping
import segmentation_models_pytorch as smp
import segmentation_models_pytorch.utils as smpu

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import Dataset, DataLoader

import torchvision
from torchvision import transforms
from PIL import Image
import pickle
from tqdm.notebook import tqdm

# %% [markdown]
# Definisanje putanja ka folderima.
#
# *train_path* je putanja slika koje čemo trenirati, *train_masks_path* putanja njihovih maski, test_path je putanja ka podacima za testiranje

# %%
train_path = 'train'
train_masks_path = 'train_masks.csv'
train_csv_path = 'train_annotation.csv'

test_path = 'test'

# %% [markdown]
# Prikaz maski u modelu za trening

# %%
train_mask = pd.read_csv("train_masks.csv")
train_mask.head()
# Out:
#    subject  img                                             pixels
# 0        1    1  168153 9 168570 15 168984 22 169401 26 169818 ...
# 1        1    2  96346 7 96762 16 97179 27 97595 35 98012 40 98...
# 2        1    3  121957 2 122365 26 122784 28 123202 31 123618 ...
# 3        1    4  110980 9 111393 21 111810 33 112228 43 112647 ...
# 4        1    5                                                NaN

# %%
train_mask.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5635 entries, 0 to 5634
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   subject  5635 non-null   int64
#  1   img      5635 non-null   int64
#  2   pixels   2323 non-null   object
# dtypes: int64(2), object(1)
# memory usage: 132.2+ KB

# %% [markdown]
# Dodavanje funkcije ***save_checkpoint*** koja prati validation loss.
# Ova funkcija sačuvaće checkpoint za model svaki put kada se validation loss smanji. Da bi ovo radilo neophodno je da imamo importovan Early stopping.

# %%
def save_checkpoint(self, val_loss, model):
    import pickle
    if self.verbose:
        self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
    with open(self.path, 'wb') as f:
        pickle.dump(model, f)
    self.val_loss_min = val_loss

# %%
EarlyStopping.save_checkpoint = save_checkpoint

# %% [markdown]
# Prikaz prve slike 1 za prvog pacijenta i odgovarajuće maske za tu sliku:

# %%
image1 = np.array(Image.open("train/1_1.tif"))
image1_mask = np.array(Image.open("train/1_1_mask.tif"))
image1_mask = np.ma.masked_where(image1_mask == 0, image1_mask)

fig, ax = plt.subplots(1,3,figsize = (16,12))
ax[0].imshow(image1, cmap = 'gray')

ax[1].imshow(image1_mask, cmap = 'gray')

ax[2].imshow(image1, cmap = 'gray', interpolation = 'none')
ax[2].imshow(image1_mask, cmap = 'cool', interpolation = 'none', alpha = 0.5)

# %% [markdown]
# Zatim definišemo funkciju ***create_csv*** koja će u .csv fajlu upisati slike i odgovarajuće maske za svaku sliku.
#
# Varijabla:
# ```
#  to_delete = f'_{key_word}'
# ```
# će obrisati svaku sliku koja predstavlja masku.
#
# Zatim funkcija vrši iteraciju kroz fajlove ***data_path***. Ukoliko naiđe na sliku koja je maska, funkcija će nastaviti da kreira red u .csv fajlu.
# Ime datoteke slike se dobija uklanjanjem substringa to_delete iz naziva datoteke pomoću:
# ```
# replace(to_delete, '')
# ```
# Ovo se čuva u promenljivoj img.
#
# Pandas DataFrame se kreira sa jednim redom, gde se ime datoteke slike stavlja u kolonu 'img', a ime datoteke maske u kolonu 'mask'. Na taj način smo u kodu jasno podelili slike iz foldera **train** na slike ultrazvuka i slike koje predstavljaju maske.
#
# Ako izlazni .csv fajl naveden sa ***out_csv_path*** ne postoji, DataFrame se čuva kao novi .csv fajl koristeći:
# ```
# data.to_csv(out_csv_path, header=True, indek=False)
# ```
# Ako .csv fajl već postoji DataFrame se dodaje postojećem fajlu.

# %%
def create_csv(data_path, out_csv_path, key_word='mask'):
    to_delete = f'_{key_word}'

    for file_name in os.listdir(data_path):
        if key_word in file_name:
            img = file_name.replace(to_delete, '')
            data = pd.DataFrame([img], index=['img']).transpose()
            data.insert(0, 'mask', file_name)

            if not os.path.exists(out_csv_path):
                data.to_csv(out_csv_path, header=True, index=False)
            else:
                data.to_csv(out_csv_path, mode='a', header=False, index=False)

# %% [markdown]
# Kreiranje fajla u kojem je upisana matrica sa slikama i maskama za svaku upisanu sliku:

# %%
create_csv(data_path=train_path, out_csv_path=train_csv_path)

# %% [markdown]
# Prikaz prethodno kreiranog .csv fajla sa slikama i odgovarajućim maskama za treniranje:

# %%
train_df = pd.read_csv(train_csv_path)
train_df.head()
# Out:
#               mask         img
# 0   34_20_mask.tif   34_20.tif
# 1   21_46_mask.tif   21_46.tif
# 2     4_7_mask.tif     4_7.tif
# 3  33_100_mask.tif  33_100.tif
# 4    3_81_mask.tif    3_81.tif

# %% [markdown]
# Kreiranje seta podataka za model. U njega smeštamo te slike i odgovarajuće maske za trening:

# %%
class ImageDataset(Dataset):
    def __init__(self, df, root_dir, transform=None):
        self.df = df
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        mask = Image.open(os.path.join(self.root_dir, self.df.iloc[idx, 0]))
        image = Image.open(os.path.join(self.root_dir, self.df.iloc[idx, 1]))

        if self.transform:
            return self.transform(image), self.transform(mask)

        return image, mask

# %%
train_samples = ImageDataset(df=train_df, root_dir=train_path)

# %% [markdown]
# Definisanje i pozivanje funkcije ***draw_samples*** koja će prikazati nekoliko slika ultrazvuka i njihovih maski.

# %%
def draw_samples(data, n_col, n_row):
    fig = plt.figure(figsize=(20, 5))

    for i in range(1, n_col + 1):
        img_ax = fig.add_subplot(n_row, n_col, i)
        msk_ax = fig.add_subplot(n_row, n_col, i + n_col)

        img_ax.imshow(data[i-1][0], cmap="gray")
        msk_ax.imshow(data[i-1][1], cmap="gray")

    fig.show()

# %%
draw_samples(data=train_samples, n_col = 5, n_row = 2)

# %% [markdown]
# **3.2. Model**
#
# **Model** je deo koji se čuva nakon pokretanja algoritama nad podacima. Postoji lista podržanih kodera u SMP-u, uzima se odgovarajuća porodica enkodera i u okviru nje se bira konkretan enkoder koji dolazi sa unapred natreniranim podacima.
#
# Postavljanje potrebnih parametara za ***segmentation_model_pytorch***:

# %%
ENCODER = 'vgg11_bn'
ENCODER_WEIGHTS = 'imagenet'
ACTIVATION = 'sigmoid'
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# > **U-Net** je popularna konvolutivna neuronska mrežna (CNN) arhitektura koja je razvijena za segmentaciju slika u medicini.
#
# Definisanje U-Neta :

# %%
model = smp.Unet(
    encoder_name=ENCODER,
    encoder_weights=ENCODER_WEIGHTS,
    in_channels=1,
    classes=1,
    activation=ACTIVATION
)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg11_bn-6002323d.pth" to /root/.cache/torch/hub/checkpoints/vgg11_bn-6002323d.pth
# 100%|██████████| 507M/507M [00:05<00:00, 95.0MB/s]

# %% [markdown]
# Postavljanje različitih metrika:
#
#
# *   loss ne sme biti preko 1
# *   metrika treba da bude što bliže 1
# *   optimizer je optimizator za LR (Learning Rate)
# *   scheduler prilagođava LR između epoha

# %%
loss = smpu.losses.DiceLoss()
metrics = [smp.utils.metrics.IoU()]
optimizer = torch.optim.Adam
scheduler = lr_scheduler.StepLR

# %% [markdown]
# Transformisanje slike

# %%
my_transforms = transforms.Compose([
    transforms.Resize(size=(224, 224)),
    transforms.ToTensor() #transformiše iz PIL image u PyTorch FloatTensor
])

# %% [markdown]
# Podela data frame-a

# %%
def split_df(df, fraction=0.8):
    df_1 = df.sample(frac=fraction)
    return df_1, df.drop(df_1.index)

# %% [markdown]
# **3.3. Treniranje**
#
# Treniramo modela kako bi što uspešnije izvršio segmentaciju. Cilj je da utvrdimo dobre i prave vrednosti za sve tezine iz obeleženih i priloženih primera. Na ovaj način, model se gradi ispitivanjem različitih primera i pokušajem pronalska modela koji gleda da minimizira gubitak.  Poziva se ugrađena metoda za zaustavljanje treniranja u slučaju opadanja stope učenja, posle datog patience.

# %%
def train(model, train_df, train_dir, optimizer, loss, metrics,
          learning_rate=0.01, batch_size=20, epochs=10, patience=3,
          scheduler=None, step_size=5, gamma=0.1, device='cpu', transform=None):

    early_stopping = EarlyStopping(patience, path='best_model.pkl', verbose=True)
    optimizer = optimizer(model.parameters(), learning_rate)

    if scheduler:
        scheduler = scheduler(optimizer, step_size, gamma)

    train_epoch = smp.utils.train.TrainEpoch(
        model, loss, metrics, optimizer, device, verbose=True
    )

    valid_epoch = smp.utils.train.ValidEpoch(
        model, loss, metrics, device, verbose=True
    )

    train_logs, valid_logs = [], []

    for epoch in range(epochs):
        train_dataframe, val_dataframe = split_df(train_df)
        train_dataset = ImageDataset(train_dataframe, train_dir, transform=transform)
        valid_dataset = ImageDataset(val_dataframe, train_dir, transform=transform)
        train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                                   batch_size=batch_size,
                                                   shuffle=True)
        valid_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                                   batch_size=batch_size,
                                                   shuffle=False)

        print(f'\nEpoch: {epoch+1}/{epochs}')

        train_log = train_epoch.run(train_loader)
        valid_log = valid_epoch.run(valid_loader)
        train_logs.append(train_log)
        valid_logs.append(valid_log)
        early_stopping(valid_log[loss.__name__], model)

        if early_stopping.early_stop:
            print("Early stopping")
            break

        if scheduler:
            scheduler.step()

    return train_logs, valid_logs

# %% [markdown]
# Proces treniranja po epohama:

# %%
res = train(model=model,
            train_df=train_df,
            train_dir=train_path,
            optimizer=optimizer,
            loss=loss,
            learning_rate=0.01,
            metrics=metrics,
            batch_size=20,
            epochs=20,
            scheduler=scheduler,
            step_size=10,
            patience=3,
            device=DEVICE,
            transform=my_transforms)
# Out:
# Epoch: 1/20
# ...
# valid: 100%|██████████| 226/226 [01:04<00:00,  3.51it/s, dice_loss - 0.4346, iou_score - 0.4002]
# Validation loss decreased (inf --> 0.434554).  Saving model ...
#
# Epoch: 2/20
# ...
# valid: 100%|██████████| 226/226 [01:04<00:00,  3.51it/s, dice_loss - 0.4754, iou_score - 0.3654]
# EarlyStopping counter: 1 out of 3
#
# Epoch: 3/20
# ...
# valid: 100%|██████████| 226/226 [01:04<00:00,  3.52it/s, dice_loss - 0.4306, iou_score - 0.4039]
# Validation loss decreased (0.434554 --> 0.430601).  Saving model ...
#
# Epoch: 4/20
# ...
# valid: 100%|██████████| 226/226 [01:04<00:00,  3.53it/s, dice_loss - 0.4026, iou_score - 0.4334]
# Validation loss decreased (0.430601 --> 0.402594).  Saving model ...
#
# Epoch: 5/20
# ...
# valid: 100%|██████████| 226/226 [01:04<00:00,  3.52it/s, dice_loss - 0.3607, iou_score - 0.4768]
# Validation loss decreased (0.402594 --> 0.360747).  Saving model ...
#
# Epoch: 6/20
# ...

# %% [markdown]
# **3.4. Evaluacija rezultata**
#
# Nakon treniranja modela, grafički se prikazuju rezultati.

# %%
with open('results.pkl', 'wb') as f:
    pickle.dump(res, f)

# %%
with open('best_model.pkl', 'rb') as f:
    best_model = pickle.load(f)

# %%
train_logs_df = pd.DataFrame(res[0])
valid_logs_df = pd.DataFrame(res[1])

res_dict = {'train': train_logs_df, 'valid': valid_logs_df}

# %% [markdown]
# Definisanje i pozivanje funkcije za crtanje grafički prikaz rezultata

# %%
def draw_graphic(df_dict, title, criteria, xlab, ylab, colors=['m', 'c'],
                 legend_loc='best', figsize=(12, 8), fontsize=14):
    fig = plt.figure(figsize=figsize)
    for i, key in enumerate(df_dict):
        plt.plot(df_dict[key].index.tolist(), df_dict[key][criteria].tolist(), colors[i], lw=3, label=key)
    x = np.arange(0, 20, 1)
    y = np.arange(0, 0.8, 0.1)
    plt.xticks(x)
    plt.yticks(y)
    plt.xlabel(xlab, fontsize=fontsize)
    plt.ylabel(ylab, fontsize=fontsize)
    plt.title(title, fontsize=fontsize)
    plt.legend(loc=legend_loc, fontsize=fontsize)
    plt.grid()

    fig.show()

# %% [markdown]
# Na prvom grafiku je prikazano koliko je bilo preklapanja između predicted i ground truth, izražen u opsegu od 0 do 1, a zatim koliko je bilo odstupanja tokom epoha treniranja.

# %%
draw_graphic(df_dict=res_dict, title='IoU scores', criteria='iou_score', xlab='epochs', ylab='IoU score')

# %% [markdown]
# Dice loss poredi regione koji se preklapaju. Koristi se za nebalansirane setove podataka gde pozadina slike dominira u odnosu na bitan deo slike
#
# Dice = (2*presek)/(predvidjena+Ground truth)

# %%
draw_graphic(df_dict=res_dict, title='Dice Losses', criteria='dice_loss', xlab='epochs', ylab='Dice losses')

# %%
res_dict
# Out:
# {'train':     dice_loss  iou_score
#  0    0.536298   0.315144
#  1    0.437152   0.396832
#  2    0.407772   0.426300
#  3    0.407407   0.428237
#  4    0.386314   0.448980
#  5    0.376422   0.460257
#  6    0.376116   0.460503
#  7    0.363065   0.474547
#  8    0.361615   0.475769
#  9    0.354498   0.484639
#  10   0.329707   0.511691
#  11   0.312999   0.528909
#  12   0.309332   0.533735
#  13   0.303564   0.540500
#  14   0.300310   0.544100
#  15   0.295452   0.550029
#  16   0.283132   0.564715
#  17   0.288109   0.559627
#  18   0.284518   0.563190
#  19   0.282166   0.566125,
#  'valid':     dice_loss  iou_score
#  0    0.434554   0.400242
#  1    0.475432   0.365351
#  2    0.430601   0.403866
#  3    0.402594   0.433372
#  4    0.360747   0.476753
#  5    0.358739   0.477824
#  6    0.371758   0.466928
#  7    0.453935   0.383605
#  8    0.345025   0.493284
#  9    0.347012   0.492246
#  10   0.313734   0.529927
#  11   0.307178   0.536696
#  12   0.302553   0.543992
# ...

# %% [markdown]
# **3.5. Testiranje**
#
#
# Testiranje modela nad podacima iz test foldera, koji se potom čuvaju u submission fajlu.

# %%
def rle_encoding(x):
    dots = np.where(x.T.flatten()==1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b+1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

# %%
imgs = [f for f in os.listdir(test_path)]
imgs = sorted(imgs, key=lambda s: int(s.split('.')[0]))

# %% [markdown]
# Definisanje i pozivanje funkcije ***create_csv_submission*** koja će u .csv fajl upisati podatke o tome da li se na fotografiji nalazi nerv ili ne, u odnosu na prethodno istreniran model.

# %%
def create_csv_submission(model, data_path, img_list, out_path):
    submission_df = pd.DataFrame(columns=['img', 'pixels'])
    model.to(DEVICE)
    model.eval()

    for i, img in enumerate(tqdm(img_list)):
        x = Image.open(os.path.join(data_path, img))

        x = my_transforms(x)

        x = x.unsqueeze(0).to(DEVICE)
        pred_mask = model.predict(x)

        pred_mask = pred_mask.cpu()
        pred_mask = transforms.Resize(size=(420, 580))(pred_mask)

        encoding = rle_encoding(pred_mask)

        pixels = ' '.join(map(str, encoding))
        submission_df.loc[i] = [str(i+1), pixels]

    submission_df.to_csv(out_path, index=False)

# %% [markdown]
# Pravi se submission fajl koji sadrži pretpostavke natreniranog modela:

# %%
create_csv_submission(model=model,
                      data_path=test_path,
                      img_list=imgs,
                      out_path='submission.csv')
# Out:
#   0%|          | 0/5508 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# ...

# %% [markdown]
# Prikaz ***submission.csv*** fajla

# %%
test_res = pd.read_csv("submission.csv")
test_res.head()
# Out:
#    img                                             pixels
# 0    1  107223 13 107238 9 107643 13 107658 9 108062 2...
# 1    2  111504 36 111924 36 112343 38 112761 47 113181...
# 2    3  113546 3 113965 5 114385 5 114804 7 115224 7 1...
# 3    4                                                NaN
# 4    5  107269 13 107689 13 108109 14 108525 64 108945...

# %% [markdown]
# # **4. Zaključak**
#
# Projekat segmentacije ultrazvuka omogućio je lakše razumevanje funkcionisanja neuronskih mreža, kao i same segmentacije. Zaključujemo da mašinko učenje igra veliku ulogu u poboljšanju moderne medicine i nauke.
#
# # **5. Literatura**
#
#
# [1] 	U. E. Scott, Digital image proccesing and analysis.
#
# [2] 	Ć. Dubravko, OTKRIVANJE ZNANJA IZ PODATAKA.
#
# [3] 	[Online]. Available: https://aapm.onlinelibrary.wiley.com/doi/abs/10.1002/mp.13649. [Accessed 07 2023].
#
# [4] 	[Online]. Available: https://pytorch.org/vision/stable/index.html. [Accessed 07 2023].
#
# [5] 	[Online]. Available: https://segmentation-modelspytorch.readthedocs.io/en/latest/. [Accessed 07 2023].
